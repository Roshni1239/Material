# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
column = 'Price'
plt.figure(figsize=(16, 12))

# %%
print(df.columns)
# Out:
# Index(['Country', 'Dish', 'Main Ingredient', 'Spicy Level', 'Price (USD)',
#        'Vegetarian'],
#       dtype='object')

# %%
column = 'Price'

# %%
column = 'cost_usd'

# %%
plt.subplot(2, 2, 1)
plt.hist(df[column].dropna(), bins=30, color='skyblue')
plt.title('Standard Histogram')
plt.xlabel(column)
plt.ylabel('Frequency')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cost_usd'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[126], line 2
#       1 plt.subplot(2, 2, 1)
# ----> 2 plt.hist(df[column].dropna(), bins=30, color='skyblue')
#       3 plt.title('Standard Histogram')
#       4 plt.xlabel(column)
#
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'cost_usd'

# %%
plt.subplot(2, 2, 2)
plt.hist(df[column].dropna(), bins=30, density=True, color='lightgreen')
plt.title('Normalized Histogram (Density)')
plt.xlabel(column)
plt.ylabel('Density')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cost_usd'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[121], line 2
#       1 plt.subplot(2, 2, 2)
# ----> 2 plt.hist(df[column].dropna(), bins=30, density=True, color='lightgreen')
#       3 plt.title('Normalized Histogram (Density)')
#       4 plt.xlabel(column)
#
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'cost_usd'

# %%
plt.subplot(2, 2, 3)
plt.hist(df[column].dropna(), bins=30, cumulative=True, color='salmon')
plt.title('Cumulative Histogram')
plt.xlabel(column)
plt.ylabel('Cumulative Frequency')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cost_usd'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[122], line 2
#       1 plt.subplot(2, 2, 3)
# ----> 2 plt.hist(df[column].dropna(), bins=30, cumulative=True, color='salmon')
#       3 plt.title('Cumulative Histogram')
#       4 plt.xlabel(column)
#
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'cost_usd'

# %%
plt.subplot(2, 2, 4)
sns.kdeplot(df[column].dropna(), shade=True, color='purple')
plt.title('KDE / Density Plot')
plt.xlabel(column)
plt.ylabel('Density')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cost_usd'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[124], line 2
#       1 plt.subplot(2, 2, 4)
# ----> 2 sns.kdeplot(df[column].dropna(), shade=True, color='purple')
#       3 plt.title('KDE / Density Plot')
#       4 plt.xlabel(column)
#
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'cost_usd'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(df.columns)
# Out:
# Index(['Country', 'Dish', 'Main Ingredient', 'Spicy Level', 'Price (USD)',
#        'Vegetarian'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
df['food_category'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Count of Food Categories')
plt.xlabel('Food Category')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'food_category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[134], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 df['food_category'].value_counts().plot(kind='bar', color='skyblue')
#       3 plt.title('Count of Food Categories')
#       4 plt.xlabel('Food Category')
#
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'food_category'

# %%
plt.figure(figsize=(10,6))
df['food_category'].value_counts().plot(kind='barh', color='lightgreen')
plt.title('Count of Food Categories')
plt.xlabel('Count')
plt.ylabel('Food Category')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'food_category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[135], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 df['food_category'].value_counts().plot(kind='barh', color='lightgreen')
#       3 plt.title('Count of Food Categories')
#       4 plt.xlabel('Count')
#
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'food_category'

# %%
ct = pd.crosstab(df['continent'], df['food_category'])

ct.plot(kind='bar', stacked=True, figsize=(12,7), colormap='tab20')
plt.title('Stacked Bar Chart: Food Categories by Continent')
plt.xlabel('Continent')
plt.ylabel('Count')
plt.legend(title='Food Category')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'continent'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 ct = pd.crosstab(df['continent'], df['food_category'])
#       3 ct.plot(kind='bar', stacked=True, figsize=(12,7), colormap='tab20')
#       4 plt.title('Stacked Bar Chart: Food Categories by Continent')
#
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'continent'

# %%
ct.plot(kind='bar', stacked=False, figsize=(12,7), colormap='tab20')
plt.title('Grouped Bar Chart: Food Categories by Continent')
plt.xlabel('Continent')
plt.ylabel('Count')
plt.legend(title='Food Category')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 ct.plot(kind='bar', stacked=False, figsize=(12,7), colormap='tab20')
#       2 plt.title('Grouped Bar Chart: Food Categories by Continent')
#       3 plt.xlabel('Continent')
#
# NameError: name 'ct' is not defined

# %%
counts = df['food_category'].value_counts().sort_values()

plt.figure(figsize=(10,6))
plt.hlines(y=counts.index, xmin=0, xmax=counts.values, color='skyblue')
plt.plot(counts.values, counts.index, "o", color='steelblue')
plt.title('Lollipop Chart of Food Categories Count')
plt.xlabel('Count')
plt.ylabel('Food Category')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'food_category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 counts = df['food_category'].value_counts().sort_values()
#       3 plt.figure(figsize=(10,6))
#       4 plt.hlines(y=counts.index, xmin=0, xmax=counts.values, color='skyblue')
#
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\OneDrive\Desktop\data-analysis-and-visualization-bca-2025-main\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'food_category'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
counts = df['Country'].value_counts()

# %%
plt.figure(figsize=(8,8))
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Street Foods by Country')
plt.show()

# %%
plt.figure(figsize=(8,8))
wedges, texts, autotexts = plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=140)

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Donut Chart of Street Foods by Country')
plt.show()

# %%
explode = [0.1 if i < 5 else 0 for i in range(len(counts))]

plt.figure(figsize=(8,8))
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', explode=explode, startangle=90)
plt.title('Exploded Pie Chart (Top 5 Highlighted)')
plt.show()

# %%
# !pip install plotly

# %%
import plotly.express as px
fig = px.sunburst(df, path=['Country', 'Food_Type'], title='Nested Pie Chart: Country → Food Type')
fig.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('global_street_food.csv') 
df.head()

# %%
column = 'Price' 
desc = df[column].describe()
print(f"Min: {desc['min']}")
print(f"Q1: {df[column].quantile(0.25)}")
print(f"Median (Q2): {desc['50%']}")
print(f"Q3: {df[column].quantile(0.75)}")
print(f"Max: {desc['max']}")

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df, y='Price') 
plt.title('Standard Box Plot of Street Food Prices')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df, y='Price', notch=True)
plt.title('Notched Box Plot of Prices (95% CI)')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(data=df, y='Price', inner='quartile', palette='Pastel1')
plt.title('Violin Plot of Prices')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Country', y='Price')  # or 'Food_Type' for x
plt.title('Side-by-Side Box Plot of Price by Country')
plt.xticks(rotation=45)
plt.show()

# %%
df.columns = df.columns.str.strip()
